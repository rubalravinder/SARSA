# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

from SARSA.agent import RandomAgent, SARSAAgent
from SARSA.game import Game
from SARSA.maze import Maze
from SARSA.vizualiser import plot_cumsum, plot_maze, plot_rollav

# %% [markdown]
# ## Maze gen

# %%
maze = Maze((10, 10), 3, 2)

# %% [markdown]
# ## Visualization

# %%
plot_maze(maze)
# Out:
# /home/d5learner-05/Documents/SARSA/SARSA/vizualiser.py:54: UserWarning: You passed a edgecolor/edgecolors ('yellow') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(

# %% [markdown]
# ## Random Agent

# %%
game = Game(maze, RandomAgent(maze), max_steps=20)

# %%
game.run_game(plot=False)
# Out:
# -20

# %%
game = Game(maze, RandomAgent(maze), max_steps=20)
game.train_agent(episodes=1000)
# Out:
# episodes: 100%|██████████| 1000/1000 [00:01<00:00, 744.03it/s]

# %%
plot_cumsum(game)

# %% [markdown]
# ## SARSA agent

# %%
sarsaaagent = SARSAAgent(maze)

# %% [markdown]
# ### Train

# %%
game = Game(maze, sarsaaagent, max_steps=20)
game.train_agent(episodes=1000)
# Out:
# episodes: 100%|██████████| 1000/1000 [00:03<00:00, 312.26it/s]

# %% [markdown]
# ### Vizualization

# %% [markdown]
# #### Cumulative rewards

# %%
plot_cumsum(game)

# %% [markdown]
# #### Q Matrix

# %%
sarsaaagent.Q
# Out:
# array([[[  0.        , -11.99205478,   0.        , -12.12254496],
#         [-11.33196922,  -9.52906492,   0.        , -11.11609009],
#         [ -9.21361569,  -5.82403837,   0.        ,  -8.8737848 ],
#         [ -5.52698251,  -7.5688037 ,   0.        ,  -1.965245  ],
#         [ -7.20250217,  -9.24268785,   0.        ,  -8.65076205],
#         [-10.79126496, -13.27115123,   0.        , -12.96845975],
#         [-14.97780536, -16.56714336,   0.        , -14.50797254],
#         [-17.16201008, -17.98322819,   0.        , -16.82789731],
#         [-17.3142254 , -17.66574718,   0.        , -17.57924848],
#         [-18.30491854,   0.        ,   0.        , -16.27531492]],
#
#        [[  0.        , -10.17434619, -12.10427146, -12.57510817],
#         [-11.22135668,  -6.10769408, -10.28145595, -10.29241362],
#         [ -6.98766263,  -2.30442678,  -8.17375699,  -7.92042851],
#         [  0.        ,   0.        ,   0.        ,   0.        ],
#         [ -3.38538011,  -7.78730914,  -7.69240457,  -9.29458581],
#         [-11.00801987, -12.39156884, -12.32581637, -12.74069996],
#         [-14.4154442 , -15.17868456, -14.48118495, -14.63677836],
#         [-15.67205802, -16.24341429, -16.54813743, -15.84263198],
#         [-17.22240588, -17.31021859, -17.10815712, -15.77885574],
#         [-16.95384386,   0.        , -16.97273772, -16.05486854]],
#
#        [[  0.        , -14.22771948, -12.2861296 , -14.00856989],
#         [-12.04407608, -12.73562507, -13.08218994, -11.58281272],
#         [ -9.14471889,  -7.77673169,  -9.10553685,  -8.9955561 ],
#         [ -6.50992651,  -6.30071074,  -5.67223997,  -2.02655353],
#         [ -6.60995258,  -8.78252224,  -9.17802973,  -8.8323388 ],
#         [-25.87478625, -26.47923437, -26.60934735, -26.33656307],
#         [-25.26299156, -24.6514864 , -24.13609843, -24.54467361],
#         [-24.60682649, -23.62362669, -23.34908989, -23.42973889],
#         [-21.1970605 , -21.3299893 , -20.05394063, -23.69919294],
#         [-18.9197554 , -18.53769059, -17.060199  , -18.50536274],
#         [-15.52201946, -15.6383793 , -11.34916345, -14.58708131],
#         [-14.97581604, -14.69138818, -15.46198478, -15.76443661],
#         [-14.90580952,   0.        , -13.37736121, -14.96716563]],
#
#        [[  0.        , -28.37742823, -28.24951116, -28.25403995],
#         [-28.21631188, -28.71311574, -28.26393754, -28.36789719],
#         [-28.27631467, -28.26338118, -27.9417755 , -27.6048576 ],
#         [-26.99851024, -27.52805338, -26.10608432, -26.9435813 ],
#         [-25.98210797, -25.66996905, -25.79377122, -26.23203182],
#         [-24.23252181, -23.28116588, -23.39707381, -25.95912709],
#         [-21.15766972, -20.04506735, -20.41083778, -20.14903093],
#         [-18.48690681, -18.23512668, -16.59524071, -18.58403492],
#         [-18.23086602, -18.1611939 , -17.03300096, -18.19201378],
#         [-16.79884029,   0.        , -17.18598805, -18.24104014]],
#
#        [[  0.        , -29.06789217, -29.08300053,   0.        ],
#         [-29.26139015, -29.49187901, -29.06290064,   0.        ],
#         [-28.53091369, -29.11825444, -28.48729942,   0.        ],
#         [-27.28003783, -27.09503523, -28.16024959,   0.        ],
#         [-26.82398639, -27.30431551, -26.63327986,   0.        ],
#         [-26.39430007, -25.49163101, -25.26069658,   0.        ],
#         [-22.90651834, -21.01925729, -21.68031578,   0.        ],
#         [-19.44497825, -20.17652815, -18.5708132 ,   0.        ],
#         [-18.48442374, -20.37395843, -18.79196221,   0.        ],
#         [-18.301292  ,   0.        , -20.01360223,   0.        ]]])

# %% [markdown]
# #### Rolling average

# %%
plot_rollav(game, w=10)

# %% [markdown]
# #### Sample run

# %%
game.run_game(plot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/d5learner-05/Documents/SARSA/dev.ipynb Cell 25' in <module>
# ----> <a href='vscode-notebook-cell:/home/d5learner-05/Documents/SARSA/dev.ipynb#ch0000024?line=0'>1</a> game.run_game(plot=True)
#
# File ~/Documents/SARSA/SARSA/game.py:97, in Game.run_game(self, plot)
#      <a href='file:///home/d5learner-05/Documents/SARSA/SARSA/game.py?line=94'>95</a>         clear_output(wait=True)
#      <a href='file:///home/d5learner-05/Documents/SARSA/SARSA/game.py?line=95'>96</a>         plot_maze(self.maze)
# ---> <a href='file:///home/d5learner-05/Documents/SARSA/SARSA/game.py?line=96'>97</a>         sleep(1)
#      <a href='file:///home/d5learner-05/Documents/SARSA/SARSA/game.py?line=98'>99</a> return reward
#
# KeyboardInterrupt:

# %% [markdown]
# # Test keras

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential(
    [layers.Dense(64, activation='relu'),
    layers.Dense(38, activation='relu'),
    layers.Dense(4, activation='softmax')])
# Out:
# 2022-05-05 15:13:48.577950: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
